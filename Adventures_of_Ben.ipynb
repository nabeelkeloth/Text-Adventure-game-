# %%
                        ######################
                       #The Adevntures of Ben#
                       ######################

            
#inserting import sys 
import sys

#creatig room_1

def room_1():
    
    #greeting the gamer

    print ("Hello Gamer!\n")
    
    
    #applying str. capitalize
    name = input (prompt= "Type your name to play the game \n")
    print (f"Lets begin {name.capitalize()}!\n") 

    input(prompt ="<press enter to continue>\n")


    #warming up the gamer
    st = input(prompt= "Type something to continue \n")
        
    if st == ('something'): 
        print("Good job, you have qualified to know the story \n")
        input(prompt ="<press enter to continue>\n")
    else:
        print("OOOPSY, better luck next time")
        input (prompt ='<press any key to exit>\n')
        sys.exit()
    
room_1() 

#end of room_1
    


    #story begins  - The Adventures of Ben 
    
    #part one

input(prompt ="<press enter to read the Adventures of Ben>\n")
        
print (f"""The story begins in a bustling town called Happy. A boy named Ben 
        lived with his family in a double storey building.  He is a 
        7th grader, smart, active boy and who loved watching television but 
        was never interest in academic studies. He would bunk classes at least 
        twice a week.  He would usually get away with school by hiding 
        somewhere in the house, pretend to be sick or lock himself in the 
        room until the school bus had left. Once, his parents went on a 
        month-long vacation and his grandmother was asked to take care of 
        the house and the kids.\n """) 



    #second part of the story
    
input(prompt ="<press enter to read the second part>\n")



print (f""" Knowing this ben thought, this is the time for him to take a 
        vacation as well. He bunked the school for two weeks straight.  
        While in his two weeks staycation he mainly watched television. 
        The schoolteachers and his friends were aware of Ben’s bunking habit.
        Grandmother received a call from school informing her about the situation.
        The grandmother got concerned and along with 
        schoolteachers planned to make him go to school. Of course, Ben does
        not know about this plan as he was busy watching television.\n""")

    #final part of the story
    
input(prompt ="<press enter to read the final part>\n")




print (f"""Next day teachers arrived at his house as planned while ben was still
        watching television in the drawing room. Ben saw an unusual reflection
        on television of someone opening the main gate of the house. He stood 
        up curiously to check who was that and to his surprise it was 
        his teachers from the school. Ben first reaction was to get out of the 
        drawing room, but his siblings and grandmother tried to block him. 
        He some how managed to escape and started running……running…. 
        more running……., clibming…., jumping…. Running and finally found 
        the right spot to hide. \n""")



#creating room_2
def room_2():
    
    #while looping for countdown
    
    input(prompt ="<press enter to continue>\n")
    
    print ("Level 1\n")
    
    print("""On the count of 3, you will receive the first question! 
          
          
          ARE YOU READY?""")
    
    input(prompt ="<press enter to continue>\n")
    
    count=3 
    
    while count >0:
        print (count)
        count= count-1
        input(prompt ="<press enter to continue>\n")
    
    
    #inserting question_1


    qustn_1 = input (prompt="""Where did Ben hide?
    1) Inside the house
    2) First floor
    3) backyard 
    4) Roof top
    \n""")

    if qustn_1 == ('2'):
        print ("That is correct\n")
        print ("Level 2\n")
        input(prompt ="<press enter to continue>\n") 
        
    else:
        print("OOOPSY, better luck next time")
        input(prompt ="<press enter to exit>\n")
        sys.exit() 
        
        #end of question_1
        
room_2()
#end of romm_2


#creating room_3

def room_3():

    #inserting question_2

    print ("""Did the teachers find Ben?
    1) Yes
    2) No
    3) Never found him 
    \n""")
    
    choice = input ()
    if choice == ('2'):
        print ("That is correct\n")
        print ("Level 3\n")
        input(prompt ="<press enter to continue>\n")
        
    elif choice == ('1'): 
        print ("That is incorrect. Ben is a smart boy, teachers could'nt find him ")
        input(prompt ="<press any key exit>\n")
        sys.exit()
            
    else:
        print ("ooopsy, better luck next time\n")
        input(prompt ="<press any key exit>\n")
        sys.exit()

    #end of question_2
    
    #inserting quesntion_3

    qustn_3 = input (prompt="""What is Ben’s hobby?
    1) Watching Television
    2) Bunking school
    \n""")

    if qustn_3 == ('1'):
        print (" You win, Congratulation!!!!!!!\n")
        print ("Do you know what Ben is doing now? Download Ben’s adventure continues \n")
    else:
        print ("ooopsy, better luck next time")
        sys.exit()
        
        #end of question_3
        
room_3()
        
#end of room_3    
    
     
    
        
       ######################### THE END #############################
# Out:
# Hello Gamer!
#
# Type your name to play the game
# nabeel
# Lets begin Nabeel!
#
# <press enter to continue>
#
# Type something to continue
# something
# Good job, you have qualified to know the story
#
# <press enter to continue>
#
# <press enter to read the Adventures of Ben>
#
# The story begins in a bustling town called Happy. A boy named Ben
#         lived with his family in a double storey building.  He is a
#         7th grader, smart, active boy and who loved watching television but
#         was never interest in academic studies. He would bunk classes at least
#         twice a week.  He would usually get away with school by hiding
#         somewhere in the house, pretend to be sick or lock himself in the
#         room until the school bus had left. Once, his parents went on a
#         month-long vacation and his grandmother was asked to take care of
#         the house and the kids.
#
# <press enter to read the second part>
#
# ...
